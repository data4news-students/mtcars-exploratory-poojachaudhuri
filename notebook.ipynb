# %% [markdown]
# # mtcars
#
# In this notebook, you'll explore the iconic `mtcars` dataset. Why mtcars? Because it is a classic pedagogical dataset and there is A LOT written about it online. Every complicated concept we encounter, you should be able to google the name plus `mtcars` and find some information about it. So for example, when we study linear regression, you'll be able to google "linear regression mtcars" and find a million billion tutorials that use this dataset to teach regressions. It will give us a common vocabulary with other learners around the world.

# %% [markdown]
# ### Standard Python and R imports

# %%
# %load_ext rpy2.ipython
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline  
from matplotlib import rcParams
rcParams['figure.figsize'] = (16, 100)

import warnings
from rpy2.rinterface import RRuntimeWarning
warnings.filterwarnings("ignore") # Ignore all warnings
# warnings.filterwarnings("ignore", category=RRuntimeWarning) # Show some warnings

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, HTML

# %%
# %%javascript
# // Disable auto-scrolling
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
# %%R
#
# # My commonly used R imports
#
# require('tidyverse')
# Out:
# R[write to console]: Loading required package: tidyverse
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.4.0      ✔ purrr   0.3.5
# ✔ tibble  3.1.8      ✔ dplyr   1.0.10
# ✔ tidyr   1.2.1      ✔ stringr 1.4.1
# ✔ readr   2.1.3      ✔ forcats 0.5.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
# EXAMPLE PYTHON CELL

df = pd.DataFrame(
    np.random.randint(0,100,size=(100, 2)), columns=list('AB'))
df.head()
# Out:
#     A   B
# 0  58  17
# 1  16  32
# 2  58  92
# 3  80  37
# 4  34  26

# %%
# %%R -i df
#
# # EXAMPLE R CELL
# df
# plt <- ggplot(df) +
#     geom_point(aes(A,B))
#
# plt

# %% [markdown]
# ## Load the data

# %%
# %%R
#
# # Import data with R
# mtcars <- read_csv('mtcars.csv', show_col_types = FALSE)
# mtcars %>% head(4)
# Out:
# # A tibble: 4 × 12
#   name           mpg   cyl  disp    hp  drat    wt  qsec    vs    am  gear  carb
#   <chr>        <dbl> <dbl> <dbl> <dbl> <dbl> <dbl> <dbl> <dbl> <dbl> <dbl> <dbl>
# 1 Mazda RX4     21       6   160   110  3.9   2.62  16.5     0     1     4     4
# 2 Mazda RX4 W…  21       6   160   110  3.9   2.88  17.0     0     1     4     4
# 3 Datsun 710    22.8     4   108    93  3.85  2.32  18.6     1     1     4     1
# 4 Hornet 4 Dr…  21.4     6   258   110  3.08  3.22  19.4     1     0     3     1

# %%
# Import data in python
mtcars = pd.read_csv('mtcars.csv')
mtcars
# Out:
#                    name   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# 11           Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.40   0   0
# 12           Merc 450SL  17.3    8  275.8  180  3.07  3.730  17.60   0   0
# 13          Merc 450SLC  15.2    8  275.8  180  3.07  3.780  18.00   0   0
# 14   Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   0   0
# 15  Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82   0   0
# 16    Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.42   0   0
# 17             Fiat 128  32.4    4   78.7   66  4.08  2.200  19.47   1   1
# 18          Honda Civic  30.4    4   75.7   52  4.93  1.615  18.52   1   1
# 19       Toyota Corolla  33.9    4   71.1   65  4.22  1.835  19.90   1   1
# 20        Toyota Corona  21.5    4  120.1   97  3.70  2.465  20.01   1   0
# 21     Dodge Challenger  15.5    8  318.0  150  2.76  3.520  16.87   0   0
# 22          AMC Javelin  15.2    8  304.0  150  3.15  3.435  17.30   0   0
# 23           Camaro Z28  13.3    8  350.0  245  3.73  3.840  15.41   0   0
# 24     Pontiac Firebird  19.2    8  400.0  175  3.08  3.845  17.05   0   0
# 25            Fiat X1-9  27.3    4   79.0   66  4.08  1.935  18.90   1   1
# 26        Porsche 914-2  26.0    4  120.3   91  4.43  2.140  16.70   0   1
# 27         Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.90   1   1
# 28       Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.50   0   1
# 29         Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.50   0   1
# 30        Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.60   0   1
# 31           Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.60   1   1
#
#     gear  carb
# 0      4     4
# 1      4     4
# 2      4     1
# 3      3     1
# 4      3     2
# 5      3     1
# 6      3     4
# 7      4     2
# 8      4     2
# 9      4     4
# 10     4     4
# 11     3     3
# 12     3     3
# 13     3     3
# 14     3     4
# 15     3     4
# 16     3     4
# 17     4     1
# 18     4     2
# 19     4     1
# 20     3     1
# 21     3     2
# 22     3     2
# 23     3     4
# 24     3     2
# 25     4     1
# 26     5     2
# 27     5     2
# 28     5     4
# 29     5     6
# 30     5     8
# 31     4     2

# %% [markdown]
# # Exploratory data analysis
#
# So far we've done a lot of looking at distributions of single variables. In this dataset we have some continuous variables (like `mpg`, `disp`, `hp`, `drat`, `wt`, and `qsec`) and some discrete variables (like `vs`, `am`, `gear`, and `carb`). Let's quickly glance through the distributions of them.

# %%
# %%R
#
# continuous_variables <- c('mpg', 'disp', 'hp', 'drat', 'wt', 'qsec')
# discrete_variables   <- c('vs', 'am', 'gear', 'carb')
#
# # Conevert to long format
# mtcars_long = mtcars %>% pivot_longer(!name, names_to = 'variable', values_to = 'value')
#
# # plot only continuous variables
# to_plot <- mtcars_long %>% filter(variable %in% continuous_variables)
#
# histogram_means <- to_plot %>%
#   group_by(variable) %>%
#   summarise(mean = mean(value))
#
# plot_continuous_histograms <- ggplot(to_plot) +
#     aes(x=value, fill=variable, group=variable) +
#     geom_histogram(bins=10) +
#     geom_vline(data=histogram_means, aes(xintercept=mean)) +
#     facet_wrap(~variable, scales='free') +
#     theme_minimal() +
#     labs(title = 'mtcars at a glance', subtitle='continuous variables (means marked with a vertical line)')
#
#
# plot_continuous_dotplot <- ggplot(to_plot) +
#     aes(x=value, y=1, color=variable) +
#     geom_point(size=4, alpha=.2) +
#     stat_summary(fun.y= mean, geom="point", shape='x',
#                  size=10, color="black", alpha=1, orientation='y') +
#     facet_wrap(~variable, scales='free', ncol=1) +
#     theme_minimal() +
#     labs(
#         title = 'mtcars at a glance',
#         subtitle='continuous variables (means marked with an X)'
#     ) +
#     theme(
#             axis.text.y=element_blank(),  #remove y axis labels
#             axis.ticks.y=element_blank(),  #remove y axis ticks
#             panel.grid.major.y = element_blank(), #remove y axis grid
#             panel.grid.minor.y = element_blank(), #remove y axis grid
#     )
#
# # display both plots
# print(plot_continuous_histograms)
# print(plot_continuous_dotplot)

# %%
# %%R
#
# # plot only discrete variables
# to_plot <- mtcars_long %>% filter(variable %in% discrete_variables)
#
# plot_discrete <- ggplot(to_plot) +
#     aes(y=value, fill=variable) +
#     geom_bar() +
#     facet_wrap(~variable, scales='free') +
#     theme_minimal() +
#     labs(title = 'mtcars at a glance', subtitle='discrete variables')
#
#
# plot_discrete

# %% [markdown]
# 👉 What can we conclude about this dataset from the charts above?

# %% [markdown]
# 1. There are only two types of cars (chart 2) - a or m.
# 2. Most cars in the dataset have low qsec.
# 3. There are three outliers that are heaviers than the rest of the cars.

# %% [markdown]
# 👉 What can we not conclude about this dataset from the charts above?

# %% [markdown]
# 1. The documentation says that manual transmissions have either 4 or 5 forward gears and automatic either 3 or 4. So the second chart does not tell us if the cars in '4' are a or m.

# %% [markdown]
# 👉 What further questions about this data do you have now?

# %%
# What makes a car better? Fuel efficiency (mpg) or horsepower (hp)? And how are other parameters related to these two?

# %% [markdown]
# # Comparing variables to one another
#
# You're welcome to explore those univariate distributions more, but let's focus on something new. Comparing variables to one another. I'll start you off with a basic scatter plot.

# %%
# %%R
#
# ggplot(mtcars) +
#     aes(y=mpg, x=wt) +
#     geom_point()

# %%
# %%R
#
# library(ggrepel)
# library(ggtext)

# %% [markdown]
# # 👉 Try It
#
# 1. Imporve the chart above. Add a title and subtitle, and better axis labels. Be **very careful** about the language you use in the headline. Assume you have a very strict copyeditor, make the language easy to understand but make sure you're not saying more than what the data proves.
#
# 2. Answer the questions below:
#
#     a. What can we conclude about fuel efficiency and weight
#
#     Answer: The lighter the car, the more fuel efficient it is.
#
#     b. What can't we conclude about fuel efficiency and weight
#
#     Answer: I know nothing about cars but maybe we can't say that having better mileage doesn't tell if the performance would be
#     better?
#
#     c. What further questions do you have about this data?
#
#     Answer: Are lightweight cars more expensive?

# %%
# %%R -w 800 -h 600
#
# ggplot(mtcars) +
#     aes(y=mpg, x=wt, size=wt) + # label=name
#      # geom_text_repel(size=3) +
#     scale_size(guide = FALSE) +  # Remove the legend for size
#     geom_hline(yintercept=mean(mtcars$mpg), color='red') +
#     geom_point() +
#     theme_minimal() +
#     theme(plot.title = element_text(face = "bold", size = 16, family = "Merriweather", color = "black", margin = margin(b = 13)),
#         plot.subtitle = element_text(size = 12, family = "Merriweather", margin = margin(b = 15)),
#         plot.margin = unit(c(0.7, 0.7, 0.7, 0.7), "cm")
#     ) +
#     labs(title = 'Lightweight cars give better mileage',
#         subtitle = "Each dot is a car. Bigger the dot, heavier the car. The red line is the average mileage. Heavier cars mostly fall below\nthe average mileage line.", # how do I add color to a part of the text?
#         x= 'Weight (1000 lbs)',
#         y= 'Miles per gallon')

# %% [markdown]
# ## Part 1 (Gudied Inquiry)
# # 👉 What makes cars more fuel efficient?

# %%
mtcars = mtcars.sort_values(by='mpg', ascending=False)
mtcars
# Out:
#                    name   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 19       Toyota Corolla  33.9    4   71.1   65  4.22  1.835  19.90   1   1
# 17             Fiat 128  32.4    4   78.7   66  4.08  2.200  19.47   1   1
# 27         Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.90   1   1
# 18          Honda Civic  30.4    4   75.7   52  4.93  1.615  18.52   1   1
# 25            Fiat X1-9  27.3    4   79.0   66  4.08  1.935  18.90   1   1
# 26        Porsche 914-2  26.0    4  120.3   91  4.43  2.140  16.70   0   1
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 20        Toyota Corona  21.5    4  120.1   97  3.70  2.465  20.01   1   0
# 31           Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.60   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 29         Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.50   0   1
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 24     Pontiac Firebird  19.2    8  400.0  175  3.08  3.845  17.05   0   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# 12           Merc 450SL  17.3    8  275.8  180  3.07  3.730  17.60   0   0
# 11           Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.40   0   0
# 28       Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.50   0   1
# 21     Dodge Challenger  15.5    8  318.0  150  2.76  3.520  16.87   0   0
# 13          Merc 450SLC  15.2    8  275.8  180  3.07  3.780  18.00   0   0
# 22          AMC Javelin  15.2    8  304.0  150  3.15  3.435  17.30   0   0
# 30        Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.60   0   1
# 16    Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.42   0   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 23           Camaro Z28  13.3    8  350.0  245  3.73  3.840  15.41   0   0
# 15  Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82   0   0
# 14   Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   0   0
#
#     gear  carb
# 19     4     1
# 17     4     1
# 27     5     2
# 18     4     2
# 25     4     1
# 26     5     2
# 7      4     2
# 2      4     1
# 8      4     2
# 20     3     1
# 31     4     2
# 3      3     1
# 1      4     4
# 0      4     4
# 29     5     6
# 9      4     4
# 24     3     2
# 4      3     2
# 5      3     1
# 10     4     4
# 12     3     3
# 11     3     3
# 28     5     4
# 21     3     2
# 13     3     3
# 22     3     2
# 30     5     8
# 16     3     4
# 6      3     4
# 23     3     4
# 15     3     4
# 14     3     4

# %%
# %%R -w 600 -h 800
#
# ggplot(mtcars) +
#     aes(y=mpg, x=factor(am), label=name, size=wt) +
#     geom_text_repel(size=3) +
#     geom_point()

# %% [markdown]
# Lightweight cars have better fuel efficieny.

# %%
# %%R -w 800 -h 900
#
# ggplot(mtcars) +
#     aes(y=mpg, x=qsec, label=name, size=wt, color=factor(am)) +
#     geom_vline(xintercept=median(mtcars$qsec), color='red') +
#     geom_text_repel(size=3) +
#     geom_point() +
#     annotate("text", x=17, y=34.3, label="Median qsec", color='black', size=4) +
#     annotate("curve",
#             x=17.2, y=34,
#             xend=17.6, yend=32.9,
#             arrow = arrow(length = unit(0.5, "cm")),
#             curvature=0.1, size=1, color='red') +
#     theme_minimal() +
#     labs(title = 'Cars with higher qsec give better mileage and most of these are lightweight cars.')

# %% [markdown]
# Heavier cars seem to have better qsec but lower mileage.

# %% [markdown]
# ## Part 2 (freeform inquiry)
# Ask and try to answer your own questions about the dataset. Make at least two such charts below:

# %% [markdown]
# # 👉 Question 1:
#
# Do cars with more hp give better mileage?

# %%
mtcars
# Out:
#                    name   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 19       Toyota Corolla  33.9    4   71.1   65  4.22  1.835  19.90   1   1
# 17             Fiat 128  32.4    4   78.7   66  4.08  2.200  19.47   1   1
# 27         Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.90   1   1
# 18          Honda Civic  30.4    4   75.7   52  4.93  1.615  18.52   1   1
# 25            Fiat X1-9  27.3    4   79.0   66  4.08  1.935  18.90   1   1
# 26        Porsche 914-2  26.0    4  120.3   91  4.43  2.140  16.70   0   1
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 20        Toyota Corona  21.5    4  120.1   97  3.70  2.465  20.01   1   0
# 31           Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.60   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 29         Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.50   0   1
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 24     Pontiac Firebird  19.2    8  400.0  175  3.08  3.845  17.05   0   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# 12           Merc 450SL  17.3    8  275.8  180  3.07  3.730  17.60   0   0
# 11           Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.40   0   0
# 28       Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.50   0   1
# 21     Dodge Challenger  15.5    8  318.0  150  2.76  3.520  16.87   0   0
# 13          Merc 450SLC  15.2    8  275.8  180  3.07  3.780  18.00   0   0
# 22          AMC Javelin  15.2    8  304.0  150  3.15  3.435  17.30   0   0
# 30        Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.60   0   1
# 16    Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.42   0   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 23           Camaro Z28  13.3    8  350.0  245  3.73  3.840  15.41   0   0
# 15  Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82   0   0
# 14   Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   0   0
#
#     gear  carb
# 19     4     1
# 17     4     1
# 27     5     2
# 18     4     2
# 25     4     1
# 26     5     2
# 7      4     2
# 2      4     1
# 8      4     2
# 20     3     1
# 31     4     2
# 3      3     1
# 1      4     4
# 0      4     4
# 29     5     6
# 9      4     4
# 24     3     2
# 4      3     2
# 5      3     1
# 10     4     4
# 12     3     3
# 11     3     3
# 28     5     4
# 21     3     2
# 13     3     3
# 22     3     2
# 30     5     8
# 16     3     4
# 6      3     4
# 23     3     4
# 15     3     4
# 14     3     4

# %% [markdown]
# ### 👉 Charts or summary statistics to help answer your question

# %%
# %%R -w 800 -h 900
#
# ggplot(mtcars) +
#     aes(y=mpg, x=hp, label=name, size=wt, color=factor(am)) +
#     geom_text_repel(size=3) +
#     geom_point() +
#     theme_minimal()

# %% [markdown]
# ### 👉 Reflection
#
# a. What can we conclude?
#
# Heavier cars have better hp but lower fuel efficiency.
#
# Automatic cars have more hp.
#
# b. What can't we conclude?
#
# Is it fair to assume that hp and weight are affecting the fuel efficiency or is this causation-corelation? Ther could be other factors causing this.
#
# c. What further questions does this analysis raise?
#
# Is the sample size reflective?
